# %% [markdown]
# # Class Distribution & Imbalance Analysis
# Empirical investigation of toxicity hazard distribution and clinical urgency class balance.

# %% [markdown]
# ### 1. Load Distribution Data

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

df_urgency = pd.read_parquet('../../data/processed/reference_distributions.parquet')
print(f'Loaded reference distributions: {len(df_urgency)} records')
df_urgency.head()

# %% [markdown]
# ### 2. Analyze Hazard Distribution

# %%
from stage5.src.eda.class_imbalance import ClassImbalanceAnalyzer
analyzer = ClassImbalanceAnalyzer()
# Simulated analysis of hazard imbalance
print('Class imbalance analyzer initialized.')
