# %% [markdown]
# # Cross-Stage Discordance & Disagreement Mining
# Investigates systematic contradictions between tabular ML toxicity alerts, NLP hazard extractions, and SLM summaries.

# %% [markdown]
# ### 1. Extract Disagreement Patterns

# %%
from stage5.src.eda.disagreement_analysis import DisagreementAnalyzer
da = DisagreementAnalyzer()
df_disagree = da.analyze()
df_disagree

# %% [markdown]
# ### 2. Review Root Causes

# %%
for idx, row in df_disagree.iterrows():
    print(f"{row['pattern_id']}: {row['input_category']} -> {row['root_cause']}")
