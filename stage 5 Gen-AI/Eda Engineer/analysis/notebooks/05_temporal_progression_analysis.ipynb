# %% [markdown]
# # Temporal Progression & Velocity Stress
# Analyzes rapid transitions between treatment lines and acute clinical decompensation intervals.

# %% [markdown]
# ### 1. Load Longitudinal Temporal Patterns

# %%
import pandas as pd
df_temp = pd.read_parquet('../../data/processed/temporal_patterns.parquet')
df_temp

# %% [markdown]
# ### 2. Model Hyper-Acute Sepsis Trajectory

# %%
from stage5.src.eda.temporal_analysis import TemporalAnalyzer
temp_an = TemporalAnalyzer()
res = temp_an.analyze(df_temp)
res
