# %% [markdown]
# # Sparse Biomarker Region & Borderline Envelopes
# Maps vulnerable biomarker decision boundaries (e.g. Creatinine 1.4-2.0, ctDNA extreme quantiles).

# %% [markdown]
# ### 1. Load Biomarker Distributions

# %%
import pandas as pd
df_bio = pd.read_parquet('../../data/processed/biomarker_distributions.parquet')
df_bio.head(10)

# %% [markdown]
# ### 2. Extract Vulnerable Sparse Transition Zones

# %%
from stage5.src.eda.sparse_region_analysis import SparseRegionAnalyzer
sparse_an = SparseRegionAnalyzer()
df_sparse = sparse_an.analyze(df_bio)
df_sparse
