# %% [markdown]
# # Missingness Stress Envelope Analysis
# Evaluates the impact of multi-field missingness on downstream model stability.

# %% [markdown]
# ### 1. Load Missingness Patterns

# %%
import pandas as pd
df_miss = pd.read_parquet('../../data/processed/missingness_patterns.parquet')
df_miss

# %% [markdown]
# ### 2. Evaluate Imputation Vulnerabilities

# %%
from stage5.src.eda.missingness_analysis import MissingnessAnalyzer
miss_an = MissingnessAnalyzer()
res = miss_an.analyze(df_miss)
res
