# %% [markdown]
# # Stage 1: Exploratory Data Analysis
#
# This notebook performs the complete EDA workflow for the oncology treatment optimization project. It analyzes the cleaned `master_patient_dataset.csv`.

# %% [markdown]
# ## 1. Introduction
# We investigate dataset patterns, target distributions, biomarker relationships, and possible leakage to inform ML model development.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sys
from pathlib import Path

sys.path.append('..')
from src.data_loader import load_data
from src.stats_utils import profile_dataset, get_feature_associations
from src.visualization import plot_target_distribution, plot_numerical_distributions, plot_categorical_analysis, plot_correlation_matrix
from src.biomarker_analysis import analyze_biomarkers
from src.leakage_analysis import check_target_leakage

# %% [markdown]
# ## 2. Dataset Loading

# %%
df = load_data()
target = 'toxicity_risk'
df.head()

# %% [markdown]
# ## 3. Dataset Overview

# %%
profile = profile_dataset(df)
print(f"Rows: {profile['rows']}, Columns: {profile['columns']}")
print(f"Numerical: {len(profile['numerical_cols'])}, Categorical: {len(profile['categorical_cols'])}")

# %% [markdown]
# ## 4. Target Variable Analysis

# %%
plot_target_distribution(df, target)

# %% [markdown]
# ## 5. Numerical Feature Analysis

# %%
num_cols = [c for c in profile['numerical_cols'] if c != target]
plot_numerical_distributions(df, num_cols)

# %% [markdown]
# ## 6. Categorical Feature Analysis

# %%
cat_cols = [c for c in profile['categorical_cols'] if c != target]
plot_categorical_analysis(df, cat_cols, target)

# %% [markdown]
# ## 7. Biomarker Analysis

# %%
biomarkers = analyze_biomarkers(df, target)

# %% [markdown]
# ## 8. Feature Associations

# %%
associations = get_feature_associations(df, target)
associations.head(15)

# %% [markdown]
# ## 9. Correlation Analysis

# %%
plot_correlation_matrix(df, num_cols)

# %% [markdown]
# ## 10. Leakage Analysis

# %%
leakage_df = check_target_leakage(df, target)
leakage_df[leakage_df['Status'] != 'SAFE']
